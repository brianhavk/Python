# %%
# -*- coding: utf-8 -*-
"""
Created: Brayan Quiceno
License: Grupo de Geofísica y Ciencias de la Computación - GGC3
         Institución Universitaria ITM
         Medellín, Antioquia, Colombia
"""
#%% Libraries
import pygimli as pg

#%% Load Dataset and Inversion
filepath = "Unsorted ABEM SBG.dat"
dataset = pg.physics.ert.load(filepath)

dataset["k"] = pg.physics.ert.createGeometricFactors(dataset)
dataset["err"] = pg.physics.ert.estimateError(dataset)

ERTManager = pg.physics.ert.ERTManager(dataset)
ERTManager.invert()
ERTManager.showResult()
# Out:
# 11/11/22 - 08:06:06 - pyGIMLi - INFO - Save RVector binary
# 11/11/22 - 08:06:06 - pyGIMLi - INFO - Cache stored: C:\Users\braia\AppData\Roaming\pygimli\Cache\8216140143454911771
# 11/11/22 - 08:06:06 - pyGIMLi - INFO - Found 2 regions.
# 11/11/22 - 08:06:06 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 11/11/22 - 08:06:06 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 11/11/22 - 08:06:06 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 11/11/22 - 08:06:06 - pyGIMLi - INFO - Use median(data values)=162.41682160682
# 11/11/22 - 08:06:06 - pyGIMLi - INFO - Created startmodel from forward operator: 681 [162.41682160682,...,162.41682160682]
# (<AxesSubplot:>, <matplotlib.colorbar.Colorbar at 0x1acb386ba30>)
